# %% [markdown]
# # Step 1: Validation Test
# In this first phase, we will load our datasets to verify their structural integrity. We need to answer:
# * Did the CSV files load without parsing errors?
# * What are the dimensions (rows and columns) of each dataset?
# * What are the structural data types (integers, floats, strings/objects)?

# %%
import pandas as pd

# 1. Load the datasets
try:
    crop_df = pd.read_csv(r'D:\Apollo_AgriVerse\02_Datasets\KnowledgeBase\01_crop_database.csv')
    variety_df = pd.read_csv(r'D:\Apollo_AgriVerse\02_Datasets\KnowledgeBase\02_crop_variety_database.csv')
    print("✅ Files loaded successfully!\n")
except Exception as e:
    print(f"❌ Error loading files: {e}")

# 2. Validate Structure: Shape and Columns
print("=== 01_crop_database.csv ===")
print(f"Shape: {crop_df.shape[0]} rows, {crop_df.shape[1]} columns")
print(f"First 5 Columns: {list(crop_df.columns[:5])}\n")

print("=== 02_crop_variety_database.csv ===")
print(f"Shape: {variety_df.shape[0]} rows, {variety_df.shape[1]} columns")
print(f"First 5 Columns: {list(variety_df.columns[:5])}\n")

# 3. Validate Structure: Data Types and Non-Null Counts
print("--- Crop DB Structural Info ---")
display(crop_df.info())

print("\n--- Variety DB Structural Info ---")
display(variety_df.info())
# Out:
# ❌ Error loading files: [Errno 2] No such file or directory: '01_crop_database.csv'
# === 01_crop_database.csv ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 13
#      11 # 2. Validate Structure: Shape and Columns
#      12 print("=== 01_crop_database.csv ===")
# ---> 13 print(f"Shape: {crop_df.shape[0]} rows, {crop_df.shape[1]} columns")
#      14 print(f"First 5 Columns: {list(crop_df.columns[:5])}\n")
#      16 print("=== 02_crop_variety_database.csv ===")
#
# NameError: name 'crop_df' is not defined
