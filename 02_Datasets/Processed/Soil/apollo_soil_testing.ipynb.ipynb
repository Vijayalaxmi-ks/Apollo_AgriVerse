# %%
import pandas as pd

# Point to the correct path including the Soil subfolder inside Processed
test_file_path = r'D:\MindforgeAI Internship 2026 - 2026IT002- Sunaina Gaikwad\Apollo_AgriVerse\02_Datasets\Processed\Soil\cleaned_soil_dataset.csv'

df_test = pd.read_csv(test_file_path)
print(df_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Timestamp                       5000 non-null   object
#  1   Region_State                    5000 non-null   object
#  2   Soil_Type                       5000 non-null   object
#  3   Soil_PH                         5000 non-null   float64
#  4   Nitrogen_N                      5000 non-null   float64
#  5   Phosphorus_P                    5000 non-null   float64
#  6   Potassium_K                     5000 non-null   float64
#  7   Soil_Moisture_Percent           5000 non-null   float64
#  8   Soil_Temperature_C              5000 non-null   float64
#  9   Dryness_Status                  5000 non-null   object
#  10  Hydrogel_Water_Release_Trigger  5000 non-null   int64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 429.8+ KB
# None

# %%
# 1. Check basic statistical summary for numerical features
print("--- Numerical Feature Statistics ---")
print(df_test[['Soil_PH', 'Nitrogen_N', 'Phosphorus_P', 'Potassium_K', 
               'Soil_Moisture_Percent', 'Soil_Temperature_C']].describe())

# 2. Check unique values for categorical features (Region, Soil Type, Dryness)
print("\n--- Categorical Unique Values ---")
print("Regions:", df_test['Region_State'].unique())
print("Soil Types:", df_test['Soil_Type'].unique())
print("Dryness Statuses:", df_test['Dryness_Status'].unique())

# 3. Test for expected value boundaries (e.g., pH should be between 0 and 14, Moisture between 0 and 100)
assert df_test['Soil_PH'].between(0, 14).all(), "Test Failed: Soil pH out of bounds!"
assert df_test['Soil_Moisture_Percent'].between(0, 100).all(), "Test Failed: Soil moisture percentage out of bounds!"

print("\nAll boundary and structure tests passed successfully!")
# Out:
# --- Numerical Feature Statistics ---
#            Soil_PH   Nitrogen_N  Phosphorus_P  Potassium_K  \
# count  5000.000000  5000.000000   5000.000000  5000.000000
# mean      6.508392    79.717822     44.955420    67.814674
# std       1.154680    34.235135     20.265473    30.390574
# min       4.500000    20.010000     10.000000    15.000000
# 25%       5.530000    50.355000     27.307500    41.545000
# 50%       6.510000    79.565000     44.705000    68.030000
# 75%       7.500000   108.330000     62.587500    93.972500
# max       8.500000   139.990000     79.980000   119.990000
#
#        Soil_Moisture_Percent  Soil_Temperature_C
# count            5000.000000         5000.000000
# mean               26.658384           29.857408
# std                10.628114            6.934117
# min                 8.010000           18.000000
# 25%                17.640000           23.880000
# 50%                26.840000           29.825000
# ...
