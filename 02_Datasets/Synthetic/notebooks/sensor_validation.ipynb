# %% [markdown]
# # Apollo AgriVerse
#
# ## Sensor Stream Validation
#
# Purpose:
# Validate the generated synthetic sensor dataset before integration into the master dataset.

# %%
import pandas as pd

# %%
df = pd.read_csv("../Raw/sensor_stream.csv")

df.head()
# Out:
#              timestamp farm_id  temperature  humidity  soil_moisture  \
# 0  2026-01-01 00:00:00   F0655        20.67     78.20          33.37
# 1  2026-01-01 00:05:00   F0914        31.09     68.38          17.38
# 2  2026-01-01 00:10:00   F0028        31.47     76.54          67.60
# 3  2026-01-01 00:15:00   F0829        38.86     79.32          26.97
# 4  2026-01-01 00:20:00   F0981        36.32     36.64          43.49
#
#    soil_temperature  light_intensity  battery_level
# 0             18.21            14434          74.14
# 1             17.15            31495          60.43
# 2             24.65            59878          67.14
# 3             24.72            37421          32.44
# 4             23.26            46082          68.30

# %%
df.shape
# Out:
# (10000, 8)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   timestamp         10000 non-null  str
#  1   farm_id           10000 non-null  str
#  2   temperature       10000 non-null  float64
#  3   humidity          10000 non-null  float64
#  4   soil_moisture     10000 non-null  float64
#  5   soil_temperature  10000 non-null  float64
#  6   light_intensity   10000 non-null  int64
#  7   battery_level     10000 non-null  float64
# dtypes: float64(5), int64(1), str(2)
# memory usage: 859.5 KB

# %%
df.describe()
# Out:
#         temperature      humidity  soil_moisture  soil_temperature  \
# count  10000.000000  10000.000000   10000.000000      10000.000000
# mean      29.959964     62.710579      52.474734         26.480597
# std        6.926752     18.733891      21.524721          6.595571
# min       18.000000     30.000000      15.000000         15.000000
# 25%       23.980000     46.757500      33.907500         20.880000
# 50%       29.945000     62.365000      52.845000         26.380000
# 75%       36.000000     78.810000      70.880000         32.170000
# max       41.990000     94.990000      90.000000         38.000000
#
#        light_intensity  battery_level
# count     10000.000000   10000.000000
# mean      50665.580600      60.018604
# std       28671.173225      23.180713
# min        1010.000000      20.010000
# 25%       25814.750000      39.670000
# 50%       51103.000000      59.985000
# 75%       75467.000000      80.190000
# max       99996.000000      99.990000

# %%
df.isnull().sum()
# Out:
# timestamp           0
# farm_id             0
# temperature         0
# humidity            0
# soil_moisture       0
# soil_temperature    0
# light_intensity     0
# battery_level       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df["temperature"].min(),df["temperature"].max())
print(df["humidity"].min(),df["humidity"].max())
print(df["soil_moisture"].min(),df["soil_moisture"].max())
print(df["battery_level"].min(),df["battery_level"].max())
# Out:
# 18.0 41.99
# 30.0 94.99
# 15.0 90.0
# 20.01 99.99

# %%
df = df.drop_duplicates()

df.to_csv("../Cleaned/sensor_stream_clean.csv",index=False)

print("Clean dataset saved.")
# Out:
# Clean dataset saved.
