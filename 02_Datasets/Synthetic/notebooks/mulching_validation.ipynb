# %% [markdown]
# # Apollo AgriVerse
#
# ## Mulching Dataset Validation

# %%
import pandas as pd

# %%
df = pd.read_csv("../Raw/mulching.csv")

df.head()
# Out:
#              timestamp farm_id     mulch_type  degradation_percent  \
# 0  2026-01-01 00:00:00   F0229        Plastic                63.94
# 1  2026-01-01 00:05:00   F0605        Organic                10.25
# 2  2026-01-01 00:10:00   F0028  Biodegradable                 2.98
# 3  2026-01-01 00:15:00   F0460  Biodegradable                71.60
# 4  2026-01-01 00:20:00   F0715        Organic                80.94
#
#    evaporation_reduction  temperature_reduction             status
# 0                  11.50                   2.93            Damaged
# 1                  54.44                   4.82            Healthy
# 2                  23.12                   4.54            Healthy
# 3                  52.08                   3.94  Needs Replacement
# 4                  10.39                   6.64  Needs Replacement

# %%
df.shape
# Out:
# (10000, 7)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   timestamp              10000 non-null  str
#  1   farm_id                10000 non-null  str
#  2   mulch_type             10000 non-null  str
#  3   degradation_percent    10000 non-null  float64
#  4   evaporation_reduction  10000 non-null  float64
#  5   temperature_reduction  10000 non-null  float64
#  6   status                 10000 non-null  str
# dtypes: float64(3), str(4)
# memory usage: 970.5 KB

# %%
df.describe(include="all")
# Out:
#                   timestamp farm_id     mulch_type  degradation_percent  \
# count                 10000   10000          10000         10000.000000
# unique                10000    1000              3                  NaN
# top     2026-01-01 00:00:00   F0191  Biodegradable                  NaN
# freq                      1      20           3369                  NaN
# mean                    NaN     NaN            NaN            49.734397
# std                     NaN     NaN            NaN            28.807724
# min                     NaN     NaN            NaN             0.010000
# 25%                     NaN     NaN            NaN            24.817500
# 50%                     NaN     NaN            NaN            49.565000
# 75%                     NaN     NaN            NaN            74.520000
# max                     NaN     NaN            NaN            99.980000
#
#         evaporation_reduction  temperature_reduction   status
# count            10000.000000           10000.000000    10000
# unique                    NaN                    NaN        3
# top                       NaN                    NaN  Healthy
# freq                      NaN                    NaN     3360
# mean                39.789304               4.535034      NaN
# std                 17.383967               2.014410      NaN
# min                 10.000000               1.000000      NaN
# 25%                 24.687500               2.800000      NaN
# 50%                 39.640000               4.530000      NaN
# 75%                 54.810000               6.270000      NaN
# max                 70.000000               8.000000      NaN

# %%
df.isnull().sum()
# Out:
# timestamp                0
# farm_id                  0
# mulch_type               0
# degradation_percent      0
# evaporation_reduction    0
# temperature_reduction    0
# status                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df["mulch_type"].value_counts())
print(df["status"].value_counts())
# Out:
# mulch_type
# Biodegradable    3369
# Organic          3352
# Plastic          3279
# Name: count, dtype: int64
# status
# Healthy              3360
# Needs Replacement    3348
# Damaged              3292
# Name: count, dtype: int64

# %%
print(df["degradation_percent"].min(), df["degradation_percent"].max())
print(df["evaporation_reduction"].min(), df["evaporation_reduction"].max())
print(df["temperature_reduction"].min(), df["temperature_reduction"].max())
# Out:
# 0.01 99.98
# 10.0 70.0
# 1.0 8.0

# %%
df = df.drop_duplicates()

df.to_csv("../Cleaned/mulching_clean.csv", index=False)

print("Clean dataset saved.")
# Out:
# Clean dataset saved.
