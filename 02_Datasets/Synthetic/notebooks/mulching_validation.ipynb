# %% [markdown]
# # Apollo AgriVerse
#
# ## Mulching Dataset Validation

# %%
import pandas as pd

# %%
df = pd.read_csv("../Raw/mulching.csv")

df.head()
# Out:
#              timestamp farm_id mulch_type  degradation_percent  \
# 0  2026-01-01 00:00:00   F0103    Plastic                10.97
# 1  2026-01-01 00:05:00   F0436    Plastic                31.89
# 2  2026-01-01 00:10:00   F0861    Plastic                17.63
# 3  2026-01-01 00:15:00   F0271    Plastic                40.84
# 4  2026-01-01 00:20:00   F0107    Plastic                11.16
#
#    evaporation_reduction  temperature_reduction             status
# 0                  23.69                   4.51            Healthy
# 1                  32.80                   1.68            Healthy
# 2                  58.82                   2.79            Healthy
# 3                  36.90                   2.84  Needs Replacement
# 4                  43.36                   6.68            Healthy

# %%
df.shape
# Out:
# (10000, 7)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   timestamp              10000 non-null  str
#  1   farm_id                10000 non-null  str
#  2   mulch_type             10000 non-null  str
#  3   degradation_percent    10000 non-null  float64
#  4   evaporation_reduction  10000 non-null  float64
#  5   temperature_reduction  10000 non-null  float64
#  6   status                 10000 non-null  str
# dtypes: float64(3), str(4)
# memory usage: 963.5 KB

# %%
df.describe(include="all")
# Out:
#                   timestamp farm_id mulch_type  degradation_percent  \
# count                 10000   10000      10000         10000.000000
# unique                10000    1000          3                  NaN
# top     2026-01-01 00:00:00   F0726    Plastic                  NaN
# freq                      1      22       4976                  NaN
# mean                    NaN     NaN        NaN            49.892019
# std                     NaN     NaN        NaN            28.868468
# min                     NaN     NaN        NaN             0.000000
# 25%                     NaN     NaN        NaN            24.870000
# 50%                     NaN     NaN        NaN            49.475000
# 75%                     NaN     NaN        NaN            74.912500
# max                     NaN     NaN        NaN            99.980000
#
#         evaporation_reduction  temperature_reduction   status
# count            10000.000000           10000.000000    10000
# ...

# %%
df.isnull().sum()
# Out:
# timestamp                0
# farm_id                  0
# mulch_type               0
# degradation_percent      0
# evaporation_reduction    0
# temperature_reduction    0
# status                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df["mulch_type"].value_counts())
print(df["status"].value_counts())
# Out:
# mulch_type
# Plastic          4976
# Organic          3021
# Biodegradable    2003
# Name: count, dtype: int64
# status
# Healthy              4069
# Needs Replacement    3449
# Damaged              2482
# Name: count, dtype: int64

# %%
print(df["degradation_percent"].min(), df["degradation_percent"].max())
print(df["evaporation_reduction"].min(), df["evaporation_reduction"].max())
print(df["temperature_reduction"].min(), df["temperature_reduction"].max())
# Out:
# 0.0 99.98
# 15.0 65.0
# 1.0 7.5

# %%
df = df.drop_duplicates()

df.to_csv("../Cleaned/mulching_clean.csv", index=False)

print("Clean dataset saved.")
# Out:
# Clean dataset saved.
