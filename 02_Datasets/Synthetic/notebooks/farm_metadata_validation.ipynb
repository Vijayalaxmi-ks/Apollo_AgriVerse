# %% [markdown]
# # Apollo AgriVerse
# ## Farm Metadata Validation
#
# **Purpose:** Validate the generated synthetic farm metadata before integration into the master dataset.
#
# Checks:
# - Dataset shape
# - Data types
# - Missing values
# - Duplicate records
# - Summary statistics
# - Value ranges

# %%
import pandas as pd

# %%
df = pd.read_csv("../Raw/farm_metadata.csv")
df.head()
# Out:
#   farm_id field_id   latitude  longitude  area_acres soil_type crop_type  \
# 0   F0001   FD0001  19.874540  73.685133        8.40     Loamy    Grapes
# 1   F0002   FD0002  20.450714  74.041901        9.76     Loamy    Grapes
# 2   F0003   FD0003  20.231994  74.372946        3.76       Red    Grapes
# 3   F0004   FD0004  20.098658  74.232225        7.87     Loamy    Grapes
# 4   F0005   FD0005  19.656019  74.306561        7.29     Loamy    Grapes
#
#   installation_date
# 0        2026-01-01
# 1        2026-01-01
# 2        2026-01-01
# 3        2026-01-01
# 4        2026-01-01

# %%
print("Shape:", df.shape)
# Out:
# Shape: (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   farm_id            1000 non-null   str
#  1   field_id           1000 non-null   str
#  2   latitude           1000 non-null   float64
#  3   longitude          1000 non-null   float64
#  4   area_acres         1000 non-null   float64
#  5   soil_type          1000 non-null   str
#  6   crop_type          1000 non-null   str
#  7   installation_date  1000 non-null   str
# dtypes: float64(3), str(5)
# memory usage: 95.1 KB

# %%
df.isnull().sum()
# Out:
# farm_id              0
# field_id             0
# latitude             0
# longitude            0
# area_acres           0
# soil_type            0
# crop_type            0
# installation_date    0
# dtype: int64

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
df.describe(include="all")
# Out:
#        farm_id field_id     latitude    longitude   area_acres soil_type  \
# count     1000     1000  1000.000000  1000.000000  1000.000000      1000
# unique    1000     1000          NaN          NaN          NaN         5
# top      F0001   FD0001          NaN          NaN          NaN     Loamy
# freq         1        1          NaN          NaN          NaN       398
# mean       NaN      NaN    19.990257    74.007017     6.394130       NaN
# std        NaN      NaN     0.292137     0.292190     3.151472       NaN
# min        NaN      NaN    19.504632    73.503218     1.010000       NaN
# 25%        NaN      NaN    19.735974    73.741074     3.660000       NaN
# 50%        NaN      NaN    19.996807    74.018734     6.325000       NaN
# 75%        NaN      NaN    20.244319    74.260465     9.112500       NaN
# max        NaN      NaN    20.499718    74.499414    12.000000       NaN
#
#        crop_type installation_date
# count       1000              1000
# ...

# %%
print("Latitude :", df["latitude"].min(), "-", df["latitude"].max())
print("Longitude:", df["longitude"].min(), "-", df["longitude"].max())
print("Area      :", df["area_acres"].min(), "-", df["area_acres"].max())
# Out:
# Latitude : 19.504632 - 20.499718
# Longitude: 73.503218 - 74.499414
# Area      : 1.01 - 12.0

# %%
df = df.drop_duplicates()

df.to_csv("../Cleaned/farm_metadata_clean.csv", index=False)

print("Cleaned dataset saved successfully.")
# Out:
# Cleaned dataset saved successfully.
