# %% [markdown]
# # Apollo AgriVerse
#
# ## Hydrogel Dataset Validation

# %%
import pandas as pd

# %%
df = pd.read_csv("../Raw/hydrogel.csv")

df.head()
# Out:
#              timestamp farm_id  water_storage  release_rate  \
# 0  2026-01-01 00:00:00   F0229          73.86          0.32
# 1  2026-01-01 00:05:00   F0090          97.16          3.45
# 2  2026-01-01 00:10:00   F0518          54.83          0.34
# 3  2026-01-01 00:15:00   F0559          65.92          1.15
# 4  2026-01-01 00:20:00   F0007          85.14          3.03
#
#    remaining_capacity    status
# 0               63.94   Healthy
# 1               73.65  Critical
# 2               42.19  Critical
# 3                2.65       Low
# 4               22.04   Healthy

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   timestamp           10000 non-null  str
#  1   farm_id             10000 non-null  str
#  2   water_storage       10000 non-null  float64
#  3   release_rate        10000 non-null  float64
#  4   remaining_capacity  10000 non-null  float64
#  5   status              10000 non-null  str
# dtypes: float64(3), str(3)
# memory usage: 762.0 KB

# %%
df.describe()
# Out:
#        water_storage  release_rate  remaining_capacity
# count   10000.000000  10000.000000        10000.000000
# mean       75.653230      2.595836           50.503536
# std        21.878543      1.391634           29.047129
# min         0.940000      0.200000            0.010000
# 25%        62.795000      1.400000           25.487500
# 50%        82.130000      2.580000           50.515000
# 75%        93.630000      3.810000           75.750000
# max       100.000000      5.000000           99.990000

# %%
df.isnull().sum()
# Out:
# timestamp             0
# farm_id               0
# water_storage         0
# release_rate          0
# remaining_capacity    0
# status                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df["water_storage"].min(), df["water_storage"].max())
print(df["release_rate"].min(), df["release_rate"].max())
print(df["remaining_capacity"].min(), df["remaining_capacity"].max())
print(df["status"].value_counts())
# Out:
# 0.94 100.0
# 0.2 5.0
# 0.01 99.99
# status
# Healthy     3380
# Critical    3318
# Low         3302
# Name: count, dtype: int64

# %%
df = df.drop_duplicates()

df.to_csv("../Cleaned/hydrogel_clean.csv", index=False)

print("Clean dataset saved.")
# Out:
# Clean dataset saved.
